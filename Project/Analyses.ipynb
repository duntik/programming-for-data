# %%
library(ggplot2)
library(dplyr)
Butt_Clean= read.csv('Butt_Clean.csv', header=T)
print(Butt_Clean)
# Out:
#      Farm Patch_No YEAR Shelter Butts ButtSp Flowers FlowerSp PCSemi_Nat
# 1   E4.11       P1 2007     6.0     4      1    1407        6       14.8
# 2   E4.11       P2 2007     6.0     9      1     421        6       14.8
# 3   E4.11       P3 2007     3.0     0      0       1        1       14.8
# 4   E4.11       P2 2008     6.0     7      3       0        0       14.8
# 5   E4.11       P3 2008     3.0     6      2       0        0       14.8
# 6   E4.12       P1 2007     1.5     3      2     160        4        7.7
# 7   E4.12       P2 2007     0.0     5      3       1        1        7.7
# 8   E4.12       P3 2007     0.0     1      1       0        0        7.7
# 9   E4.12       P1 2008     1.5     2      2      15        4        7.7
# 10  E4.12       P2 2008     0.0     8      3      54        3        7.7
# 11  E4.12       P3 2008     0.0     8      4      88        2        7.7
# 12  E4.13       P2 2007     0.0     4      3     624        7       26.4
# ...

# %%
#
Butts= lm(Butts_log~ Flowers+ FlowerSp + Shelter+ PCSemi_Nat, data=Butt_Clean)
summary(Butts)
par(mfrow=c(1,3))
plot(Butts)
# Out:
# Call:
# lm(formula = Butts_log ~ Flowers + FlowerSp + Shelter + PCSemi_Nat,
#     data = Butt_Clean)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.0219 -0.7200  0.1848  0.8215  1.7560
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.631e+00  3.064e-01   5.322 6.49e-07 ***
# Flowers      4.514e-05  2.381e-04   0.190    0.850
# FlowerSp     4.833e-02  3.898e-02   1.240    0.218
# Shelter      4.054e-02  5.786e-02   0.701    0.485
# PCSemi_Nat  -2.688e-02  1.732e-02  -1.552    0.124
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.016 on 98 degrees of freedom
# Multiple R-squared:  0.04062,	Adjusted R-squared:  0.00146
# F-statistic: 1.037 on 4 and 98 DF,  p-value: 0.392
# Plot with title ""
# Plot with title ""

# %%
#Butts diversity
Butt_Clean_sp= lm(ButtSp~ Flowers+ FlowerSp + Shelter+ PCSemi_Nat, data=Butt_Clean)
summary(Butt_Clean_sp)
par(mfrow=c(1,3))
plot(Butt_Clean_sp)
# Out:
# Call:
# lm(formula = ButtSp ~ Flowers + FlowerSp + Shelter + PCSemi_Nat,
#     data = Butt_Clean)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.2805 -0.9219 -0.0974  0.7377  4.2275
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.3250180  0.4269321   5.446 3.83e-07 ***
# Flowers      0.0001874  0.0003317   0.565   0.5734
# FlowerSp     0.0287983  0.0543056   0.530   0.5971
# Shelter     -0.0397465  0.0806179  -0.493   0.6231
# PCSemi_Nat  -0.0509894  0.0241327  -2.113   0.0372 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.415 on 98 degrees of freedom
# Multiple R-squared:  0.04824,	Adjusted R-squared:  0.009388
# F-statistic: 1.242 on 4 and 98 DF,  p-value: 0.2984
# Plot with title ""
# Plot with title ""

# %%
#Butts Abundance
plot(dat$Flowers, dat$Butts_log, xlab= "Number of flowers", ylab= "Butt Abundance")
abline(lm(Butts_log ~Flowers, data=Butt_Clean), col="red")
plot(dat$FlowerSp, dat$Butts_log, , xlab= "Number of flower species", ylab="")
abline(lm(Butts_log ~FlowerSp, data=Butt_Clean), col="red")
plot(dat$PCSemi_Nat, dat$Butts_log,  , xlab= "Percentage of semi-natural habitat", ylab= "")
abline(lm(Butts_log ~PCSemi_Nat, data=Butt_Clean), col="red")
mtext("Butt Abundance", side = 3, line = -3, outer = TRUE)
# Out:
# plot without title
# plot without title
# plot without title

# %%
#Diversity

plot(dat$Flowers, dat$ButtSp, xlab= "Number of flowers", ylab= "Butt Species")
abline(lm(ButtSp ~Flowers, data=Butt_Clean), col="red")
plot(dat$FlowerSp, dat$ButtSp, , xlab= "Number of flower species", ylab="")
abline(lm(ButtSp ~FlowerSp, data=Butt_Clean), col="red")
plot(dat$Shelter, dat$ButtSp,  , xlab= "Shelter", ylab= "")
abline(lm(ButtSp ~ Shelter, data=Butt_Clean), col="red")
mtext("Butt Diversity", side = 3, line = -3, outer = TRUE)
# Out:
# plot without title
# plot without title
# plot without title
